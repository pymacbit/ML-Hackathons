# %%
# Import the libraries 
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
# Importing the dataset 

test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')
sample = pd.read_csv('sample.csv')

# %%
# Shape of dataset 

test.shape, train.shape
# Out:
# ((21805, 13), (50882, 14))

# %%
# Lets have a first look of train dataset 

train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# 0                  3.0               22              11628.0         0
# 1                  NaN               22              30510.0         0
# 2                  1.0               19               7450.0         1
# 3                  3.0               19              17780.0         0
# 4                  1.0               16              10404.0         0

# %%
# Data Report function for Null and Unique Values 

def data_report(data):
    Null = pd.Series(data.isnull().sum())
    Unique_Count = pd.Series(data.describe(include='all',datetime_is_numeric=True).loc['unique', :])
    Data_type = pd.Series(data.dtypes)
    info_abt_data = pd.DataFrame(({"Null":Null, "Unique Count": Unique_Count, "Data type": Data_type}))
    return info_abt_data

# %%
# Print Data report fn 

data_report(train)
# Out:
#                           Null Unique Count Data type
# ID                           0          NaN     int64
# City_Code                    0           36    object
# Region_Code                  0          NaN     int64
# Accomodation_Type            0            2    object
# Reco_Insurance_Type          0            2    object
# Upper_Age                    0          NaN     int64
# Lower_Age                    0          NaN     int64
# Is_Spouse                    0            2    object
# Health Indicator         11691            9    object
# Holding_Policy_Duration  20251           15    object
# Holding_Policy_Type      20251          NaN   float64
# Reco_Policy_Cat              0          NaN     int64
# Reco_Policy_Premium          0          NaN   float64
# Response                     0          NaN     int64

# %%
data_report(test)
# Out:
#                          Null Unique Count Data type
# ID                          0          NaN     int64
# City_Code                   0           36    object
# Region_Code                 0          NaN     int64
# Accomodation_Type           0            2    object
# Reco_Insurance_Type         0            2    object
# Upper_Age                   0          NaN     int64
# Lower_Age                   0          NaN     int64
# Is_Spouse                   0            2    object
# Health Indicator         5027            9    object
# Holding_Policy_Duration  8603           15    object
# Holding_Policy_Type      8603          NaN   float64
# Reco_Policy_Cat             0          NaN     int64
# Reco_Policy_Premium         0          NaN   float64

# %%
#ratio of null values
train.isnull().sum()/train.shape[0] *100
# Out:
# ID                          0.000000
# City_Code                   0.000000
# Region_Code                 0.000000
# Accomodation_Type           0.000000
# Reco_Insurance_Type         0.000000
# Upper_Age                   0.000000
# Lower_Age                   0.000000
# Is_Spouse                   0.000000
# Health Indicator           22.976691
# Holding_Policy_Duration    39.799929
# Holding_Policy_Type        39.799929
# Reco_Policy_Cat             0.000000
# Reco_Policy_Premium         0.000000
# Response                    0.000000
# dtype: float64

# %% [markdown]
# #### Ratio of null value is 22 and 39 %

# %%
#ratio of null values
test.isnull().sum()/test.shape[0] *100
# Out:
# ID                          0.000000
# City_Code                   0.000000
# Region_Code                 0.000000
# Accomodation_Type           0.000000
# Reco_Insurance_Type         0.000000
# Upper_Age                   0.000000
# Lower_Age                   0.000000
# Is_Spouse                   0.000000
# Health Indicator           23.054345
# Holding_Policy_Duration    39.454254
# Holding_Policy_Type        39.454254
# Reco_Policy_Cat             0.000000
# Reco_Policy_Premium         0.000000
# dtype: float64

# %% [markdown]
# #### Null Values founded
# - Health Indicator	11691
# - Holding_Policy_Duration	20251
# - Holding_Policy_Type	20251

# %%
#categorical features
categorical = train.select_dtypes(include =[np.object])
print("Categorical Features in Train Set:",categorical.shape[1])

#numerical features
numerical= train.select_dtypes(include =[np.float64,np.int64])
print("Numerical Features in Train Set:",numerical.shape[1])
# Out:
# Categorical Features in Train Set: 6
# Numerical Features in Train Set: 8

# %% [markdown]
# -----------
# ----------
# -----------

# %%
# renamed column name to deal with spacing issue further 

train = train.rename(columns= {"Health Indicator":'HealthIndicator'})
test = test.rename(columns= {"Health Indicator":'HealthIndicator'})

# %%
# before applying any imputation we have to deal with string values from of missing data columns

# %%
train['HealthIndicator']= train['HealthIndicator'].replace({'X1':9, 'X2':8, 'X3':7, 'X4':6, 'X5': 5, 'X6':4, 'X7':3 , 'X8':2, 'X9': 1 })
test['HealthIndicator']= test['HealthIndicator'].replace({'X1':9, 'X2':8, 'X3':7, 'X4':6, 'X5': 5, 'X6':4, 'X7':3 , 'X8':2, 'X9': 1 })

# %%
train['Holding_Policy_Duration']= train['Holding_Policy_Duration'].replace({'14+':15.0})
test['Holding_Policy_Duration']= test['Holding_Policy_Duration'].replace({'14+':15.0})

# %%
train.Holding_Policy_Duration.value_counts(normalize=True)
# Out:
# 1.0     0.146877
# 15.0    0.141523
# 2.0     0.139075
# 3.0     0.117071
# 4.0     0.090464
# 5.0     0.077111
# 6.0     0.061833
# 7.0     0.053704
# 8.0     0.042963
# 9.0     0.036368
# 10.0    0.026542
# 11.0    0.017825
# 12.0    0.016748
# 13.0    0.016682
# 14.0    0.015213
# Name: Holding_Policy_Duration, dtype: float64

# %%
train.head(2)
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
#
#    Lower_Age Is_Spouse  HealthIndicator Holding_Policy_Duration  \
# 0         36        No              9.0                    15.0
# 1         22        No              8.0                     NaN
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# 0                  3.0               22              11628.0         0
# 1                  NaN               22              30510.0         0

# %%
# Looks like we are ready to apply imputer

# %%
train.HealthIndicator.value_counts(normalize=True)
# Out:
# 9.0    0.331964
# 8.0    0.263632
# 7.0    0.172540
# 6.0    0.146539
# 5.0    0.044066
# 4.0    0.032661
# 3.0    0.005001
# 2.0    0.001990
# 1.0    0.001608
# Name: HealthIndicator, dtype: float64

# %%
train.Holding_Policy_Duration.value_counts(normalize=True)
# Out:
# 1.0     0.146877
# 15.0    0.141523
# 2.0     0.139075
# 3.0     0.117071
# 4.0     0.090464
# 5.0     0.077111
# 6.0     0.061833
# 7.0     0.053704
# 8.0     0.042963
# 9.0     0.036368
# 10.0    0.026542
# 11.0    0.017825
# 12.0    0.016748
# 13.0    0.016682
# 14.0    0.015213
# Name: Holding_Policy_Duration, dtype: float64

# %%
train.Holding_Policy_Type.value_counts(normalize=True)
# Out:
# 3.0    0.433515
# 1.0    0.266821
# 2.0    0.163397
# 4.0    0.136267
# Name: Holding_Policy_Type, dtype: float64

# %%
train = pd.get_dummies(train, columns=["City_Code", "Accomodation_Type",  "Reco_Insurance_Type", "Is_Spouse" ])

# %%
train.head(2)
# Out:
#    ID  Region_Code  Upper_Age  Lower_Age  HealthIndicator  \
# 0   1         3213         36         36              9.0
# 1   2         1117         75         22              8.0
#
#   Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                    15.0                  3.0               22
# 1                     NaN                  NaN               22
#
#    Reco_Policy_Premium  Response  ...  City_Code_C6  City_Code_C7  \
# 0              11628.0         0  ...             0             0
# 1              30510.0         0  ...             0             0
#
#    City_Code_C8  City_Code_C9  Accomodation_Type_Owned  \
# 0             0             0                        0
# 1             0             0                        1
#
#    Accomodation_Type_Rented  Reco_Insurance_Type_Individual  \
# 0                         1                               1
# 1                         0                               0
#
#    Reco_Insurance_Type_Joint  Is_Spouse_No  Is_Spouse_Yes
# 0                          0             1              0
# 1                          1             1              0
#
# [2 rows x 52 columns]

# %%
train['HealthIndicator'].fillna(train['HealthIndicator'].median(), inplace=True)
train['Holding_Policy_Duration'].fillna(train['Holding_Policy_Duration'].median(), inplace=True)
train['Holding_Policy_Type'].fillna(train['Holding_Policy_Type'].median(), inplace=True)

# %%
data_report(train)
# Out:
#                                 Null  Unique Count Data type
# ID                                 0           NaN     int64
# Region_Code                        0           NaN     int64
# Upper_Age                          0           NaN     int64
# Lower_Age                          0           NaN     int64
# HealthIndicator                    0           NaN   float64
# Holding_Policy_Duration            0          16.0    object
# Holding_Policy_Type                0           NaN   float64
# Reco_Policy_Cat                    0           NaN     int64
# Reco_Policy_Premium                0           NaN   float64
# Response                           0           NaN     int64
# City_Code_C1                       0           NaN     uint8
# City_Code_C10                      0           NaN     uint8
# City_Code_C11                      0           NaN     uint8
# City_Code_C12                      0           NaN     uint8
# City_Code_C13                      0           NaN     uint8
# City_Code_C14                      0           NaN     uint8
# City_Code_C15                      0           NaN     uint8
# City_Code_C16                      0           NaN     uint8
# City_Code_C17                      0           NaN     uint8
# City_Code_C18                      0           NaN     uint8
# City_Code_C19                      0           NaN     uint8
# City_Code_C2                       0           NaN     uint8
# City_Code_C20                      0           NaN     uint8
# City_Code_C21                      0           NaN     uint8
# City_Code_C22                      0           NaN     uint8
# City_Code_C23                      0           NaN     uint8
# City_Code_C24                      0           NaN     uint8
# City_Code_C25                      0           NaN     uint8
# City_Code_C26                      0           NaN     uint8
# City_Code_C27                      0           NaN     uint8
# City_Code_C28                      0           NaN     uint8
# City_Code_C29                      0           NaN     uint8
# City_Code_C3                       0           NaN     uint8
# City_Code_C30                      0           NaN     uint8
# City_Code_C31                      0           NaN     uint8
# City_Code_C32                      0           NaN     uint8
# City_Code_C33                      0           NaN     uint8
# City_Code_C34                      0           NaN     uint8
# City_Code_C35                      0           NaN     uint8
# City_Code_C36                      0           NaN     uint8
# City_Code_C4                       0           NaN     uint8
# City_Code_C5                       0           NaN     uint8
# City_Code_C6                       0           NaN     uint8
# City_Code_C7                       0           NaN     uint8
# City_Code_C8                       0           NaN     uint8
# City_Code_C9                       0           NaN     uint8
# Accomodation_Type_Owned            0           NaN     uint8
# Accomodation_Type_Rented           0           NaN     uint8
# Reco_Insurance_Type_Individual     0           NaN     uint8
# Reco_Insurance_Type_Joint          0           NaN     uint8
# Is_Spouse_No                       0           NaN     uint8
# Is_Spouse_Yes                      0           NaN     uint8

# %%
train.HealthIndicator.value_counts(normalize=True)
# Out:
# 8.0    0.432825
# 9.0    0.255690
# 7.0    0.132896
# 6.0    0.112869
# 5.0    0.033941
# 4.0    0.025156
# 3.0    0.003852
# 2.0    0.001533
# 1.0    0.001238
# Name: HealthIndicator, dtype: float64

# %%
train.Holding_Policy_Duration.value_counts(normalize=True)
# Out:
# 5.0     0.397999
# 1.0     0.088420
# 15.0    0.085197
# 2.0     0.083723
# 3.0     0.070477
# 4.0     0.054459
# 5.0     0.046421
# 6.0     0.037223
# 7.0     0.032330
# 8.0     0.025864
# 9.0     0.021894
# 10.0    0.015978
# 11.0    0.010731
# 12.0    0.010082
# 13.0    0.010043
# 14.0    0.009158
# Name: Holding_Policy_Duration, dtype: float64

# %%
train.Holding_Policy_Type.value_counts(normalize=True)
# Out:
# 3.0    0.658976
# 1.0    0.160627
# 2.0    0.098365
# 4.0    0.082033
# Name: Holding_Policy_Type, dtype: float64

# %%
train.head()
# Out:
#    ID  Region_Code  Upper_Age  Lower_Age  HealthIndicator  \
# 0   1         3213         36         36              9.0
# 1   2         1117         75         22              8.0
# 2   3         3732         32         32              8.0
# 3   4         4378         52         48              9.0
# 4   5         2190         44         44              8.0
#
#   Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                    15.0                  3.0               22
# 1                     5.0                  3.0               22
# 2                     1.0                  1.0               19
# 3                    15.0                  3.0               19
# 4                     3.0                  1.0               16
#
#    Reco_Policy_Premium  Response  ...  City_Code_C6  City_Code_C7  \
# 0              11628.0         0  ...             0             0
# 1              30510.0         0  ...             0             0
# 2               7450.0         1  ...             0             0
# 3              17780.0         0  ...             0             0
# 4              10404.0         0  ...             0             0
#
#    City_Code_C8  City_Code_C9  Accomodation_Type_Owned  \
# 0             0             0                        0
# 1             0             0                        1
# 2             0             0                        1
# 3             0             0                        1
# 4             1             0                        0
#
#    Accomodation_Type_Rented  Reco_Insurance_Type_Individual  \
# 0                         1                               1
# 1                         0                               0
# 2                         0                               1
# 3                         0                               0
# 4                         1                               1
#
#    Reco_Insurance_Type_Joint  Is_Spouse_No  Is_Spouse_Yes
# 0                          0             1              0
# 1                          1             1              0
# 2                          0             1              0
# 3                          1             1              0
# 4                          0             1              0
#
# [5 rows x 52 columns]

# %%
X_train = train.drop(['Response','ID'], axis = 1)
y_train = train['Response']

# %%
from sklearn.datasets import load_digits
from sklearn.feature_selection import SelectKBest, chi2

#apply SelectKBest to extract top 5 best features for housing df
bestfeatures = SelectKBest(score_func=chi2, k=5)
fit = bestfeatures.fit(X_train,y_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_train.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  #naming the dataframe columns
print(featureScores.nlargest(5,'Score'))  #print 5best features
# Out:
#                    Features        Score
# 7       Reco_Policy_Premium  9829.942822
# 6           Reco_Policy_Cat  1768.726386
# 0               Region_Code    74.805013
# 4   Holding_Policy_Duration    35.091145
# 14            City_Code_C15     4.610118
